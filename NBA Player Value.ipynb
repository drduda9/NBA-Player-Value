# %% [markdown]
# # NBA Player Value based on Win-Shares and Salary

# %%
#import packages
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create df from web source

# %%
#Creating df from url ensures up to date information as site is updated daily
url_stats = 'https://www.basketball-reference.com/leagues/NBA_2019_advanced.html'
html_stats = requests.get(url_stats).content
df_list_stats = pd.read_html(html_stats)
df = df_list_stats[-1]
df = pd.DataFrame(data = df)
print(df)
name_of_data_file = 'nba_player_stats.csv'
#saves file to csv
df.to_csv('nba_player_stats.csv')
df = pd.read_csv('nba_player_stats.csv')
# Out:
#       Rk                  Player  Pos  Age   Tm   G    MP   PER   TS%   3PAr  \
# 0      1            Alex Abrines   SG   25  OKC  31   588   6.3  .507   .809
# 1      2              Quincy Acy   PF   28  PHO  10   123   2.9  .379   .833
# 2      3            Jaylen Adams   PG   22  ATL  20   198   9.5  .530   .750
# 3      4            Steven Adams    C   25  OKC  65  2201  18.9  .604   .002
# 4      5             Bam Adebayo    C   21  MIA  66  1476  17.5  .625   .028
# 5      6               Deng Adel   SF   21  CLE  13   160   2.2  .405   .667
# 6      7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.3  .322   .400
# 7      8       LaMarcus Aldridge    C   33  SAS  66  2170  22.7  .572   .028
# 8      9            Rawle Alkins   SG   21  CHI   3     6  38.0  .375   .250
# 9     10           Grayson Allen   SG   23  UTA  31   292   4.5  .459   .640
# 10    11           Jarrett Allen    C   20  BRK  67  1785  19.1  .632   .085
# 11    12            Kadeem Allen   SG   26  NYK  10   225  17.2  .578   .211
# 12    13         Al-Farouq Aminu   PF   28  POR  66  1911  13.2  .578   .490
# 13    14         Justin Anderson   SF   25  ATL  36   277   7.7  .459   .473
# 14    15           Kyle Anderson   SF   25  MEM  43  1281  12.9  .569   .123
# 15    16           Ryan Anderson   PF   30  TOT  20   298   5.0  .437   .569
# 16    16           Ryan Anderson   PF   30  PHO  15   278   4.6  .423   .567
# 17    16           Ryan Anderson   PF   30  MIA   5    20   9.9  .595   .600
# 18    17            Ike Anigbogu    C   20  IND   3     6  -6.0  .000   .000
# 19    18   Giannis Antetokounmpo   PF   24  MIL  62  2047  30.2  .639   .148
# 20    19         Carmelo Anthony   PF   34  HOU  10   294  11.0  .513   .529
# 21    20              OG Anunoby   SF   21  TOR  57  1171   9.9  .543   .504
# 22    Rk                  Player  Pos  Age   Tm   G    MP   PER   TS%   3PAr
# 23    21        Ryan Arcidiacono   PG   24  CHI  67  1650  10.7  .589   .592
# 24    22            Trevor Ariza   SF   33  TOT  63  2225  12.2  .534   .588
# 25    22            Trevor Ariza   SF   33  PHO  26   884  10.5  .525   .612
# 26    22            Trevor Ariza   SF   33  WAS  37  1341  13.2  .539   .577
# 27    23           D.J. Augustin   PG   31  ORL  67  1851  15.4  .626   .476
# 28    24           Deandre Ayton    C   20  PHO  62  1920  21.0  .613   .005
# 29    25            Dwayne Bacon   SG   23  CHO  28   344  11.0  .603   .318
# ..   ...                     ...  ...  ...  ...  ..   ...   ...   ...    ...
# 664  489       Russell Westbrook   PG   30  OKC  59  2112  20.8  .500   .265
# 665  490           Derrick White   PG   24  SAS  52  1336  15.0  .566   .259
# 666  491             Okaro White   PF   26  WAS   3     6  -4.5  .000  1.000
# 667  492        Hassan Whiteside    C   29  MIA  57  1422  22.6  .547   .028
# 668  493          Andrew Wiggins   SF   23  MIN  59  2053  11.9  .483   .288
# 669  494           Alan Williams   PF   26  BRK   3    17  25.0  .512   .125
# 670  495           C.J. Williams   SG   28  MIN  10    69   2.1  .441   .412
# 671  496      Johnathan Williams    C   23  LAL   9   133  13.6  .557   .000
# 672  497        Kenrich Williams   SF   24  NOP  33   700   9.7  .496   .551
# 673  498            Lou Williams   SG   32  LAC  62  1643  22.1  .560   .258
# 674  499         Marvin Williams   PF   32  CHO  65  1874  13.0  .558   .590
# 675  500         Robert Williams    C   21  BOS  27   226  19.8  .737   .000
# 676   Rk                  Player  Pos  Age   Tm   G    MP   PER   TS%   3PAr
# 677  501           Troy Williams   SF   24  SAC  18   286  11.1  .550   .471
# 678  502             D.J. Wilson   PF   22  MIL  34   575   9.8  .508   .513
# 679  503         Justise Winslow   PF   22  MIA  59  1758  12.9  .512   .336
# 680  504          Christian Wood   PF   23  MIL  13    62  17.3  .585   .200
# 681  505            Delon Wright   PG   26  TOT  61  1230  14.5  .523   .299
# 682  505            Delon Wright   PG   26  TOR  49   897  14.6  .527   .307
# 683  505            Delon Wright   PG   26  MEM  12   333  14.1  .512   .277
# 684  506      Guerschon Yabusele   PF   23  BOS  34   184  12.5  .515   .350
# 685  507              Nick Young   SG   33  DEN   4    37   2.4  .500   .889
# 686  508          Thaddeus Young   PF   30  IND  67  2053  16.4  .565   .160
# 687  509              Trae Young   PG   20  ATL  68  2093  15.7  .531   .384
# 688  510             Cody Zeller    C   26  CHO  49  1243  17.2  .611   .064
# 689  511            Tyler Zeller    C   29  ATL   1     7  -1.0  .000   .500
# 690  512              Ante Zizic    C   22  CLE  47   816  15.9  .584   .000
# 691  513             Ivica Zubac    C   21  TOT  45   758  18.7  .608   .000
# 692  513             Ivica Zubac    C   21  LAL  33   516  19.6  .633   .000
# 693  513             Ivica Zubac    C   21  LAC  12   242  16.7  .555   .000
#
#      ...  Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24   OBPM  DBPM  \
# 0    ...          NaN   0.1  0.6   0.7    .054         NaN   -2.4  -1.0
# 1    ...          NaN  -0.1  0.1   0.0  -0.019         NaN   -5.6  -0.2
# 2    ...          NaN   0.1  0.1   0.2    .046         NaN   -1.6  -2.0
# 3    ...          NaN   4.5  3.4   7.9    .172         NaN    0.9   2.1
# 4    ...          NaN   2.8  2.3   5.1    .167         NaN   -0.5   3.1
# 5    ...          NaN  -0.2  0.0  -0.2  -0.061         NaN   -5.5  -1.6
# 6    ...          NaN  -0.1  0.0   0.0  -0.046         NaN   -4.3   0.6
# 7    ...          NaN   5.1  2.1   7.1    .158         NaN    1.1   0.1
# 8    ...          NaN   0.0  0.0   0.0    .354         NaN   20.1   7.3
# 9    ...          NaN  -0.4  0.2  -0.2  -0.029         NaN   -4.5  -3.5
# 10   ...          NaN   4.0  2.8   6.7    .181         NaN   -0.3   3.2
# 11   ...          NaN   0.5  0.1   0.6    .138         NaN    1.2  -2.0
# 12   ...          NaN   2.7  2.2   4.9    .124         NaN    0.2   0.9
# 13   ...          NaN  -0.2  0.2   0.0  -0.008         NaN   -4.7  -0.9
# 14   ...          NaN   0.8  2.0   2.9    .108         NaN   -2.1   3.5
# 15   ...          NaN  -0.2  0.0  -0.2  -0.028         NaN   -4.1  -2.1
# 16   ...          NaN  -0.2  0.0  -0.2  -0.036         NaN   -4.4  -2.0
# 17   ...          NaN   0.0  0.0   0.0    .082         NaN   -0.2  -3.5
# 18   ...          NaN  -0.1  0.0  -0.1  -0.476         NaN  -22.6   8.6
# 19   ...          NaN   7.3  4.8  12.1    .284         NaN    5.4   5.0
# 20   ...          NaN   0.1  0.2   0.3    .043         NaN   -2.9  -3.2
# 21   ...          NaN   0.4  1.3   1.7    .071         NaN   -1.1   0.0
# 22   ...          NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM
# 23   ...          NaN   2.1  0.8   2.9    .085         NaN   -0.3  -1.0
# 24   ...          NaN   1.4  1.2   2.6    .055         NaN    0.0  -0.3
# 25   ...          NaN   0.2  0.5   0.7    .038         NaN   -1.2   0.3
# 26   ...          NaN   1.2  0.7   1.9    .067         NaN    0.8  -0.7
# 27   ...          NaN   4.0  1.4   5.4    .141         NaN    1.6  -2.1
# 28   ...          NaN   4.1  1.5   5.7    .142         NaN    0.5   0.4
# 29   ...          NaN   0.4  0.1   0.5    .073         NaN   -1.7  -2.4
# ..   ...          ...   ...  ...   ...     ...         ...    ...   ...
# 664  ...          NaN   1.0  4.1   5.1    .115         NaN    2.1   4.0
# 665  ...          NaN   1.4  1.4   2.8    .100         NaN    0.1   1.0
# 666  ...          NaN   0.0  0.0   0.0  -0.250         NaN  -11.0  -8.2
# 667  ...          NaN   1.6  3.2   4.8    .161         NaN   -2.5   2.9
# 668  ...          NaN  -0.6  1.2   0.6    .013         NaN   -1.9  -1.2
# 669  ...          NaN   0.0  0.0   0.1    .202         NaN   -1.9   0.8
# 670  ...          NaN  -0.1  0.0  -0.1  -0.053         NaN   -5.1  -3.1
# 671  ...          NaN   0.2  0.1   0.3    .126         NaN   -1.4  -0.6
# 672  ...          NaN   0.2  0.6   0.8    .053         NaN   -1.3   0.3
# 673  ...          NaN   3.6  1.1   4.7    .137         NaN    3.7  -2.5
# 674  ...          NaN   2.1  1.7   3.8    .096         NaN    0.2   0.3
# 675  ...          NaN   0.5  0.5   1.0    .213         NaN   -1.7   6.6
# 676  ...          NaN   OWS  DWS    WS   WS/48         NaN   OBPM  DBPM
# 677  ...          NaN   0.2  0.3   0.5    .080         NaN   -2.0   0.1
# 678  ...          NaN   0.1  1.0   1.0    .087         NaN   -2.9   1.3
# 679  ...          NaN   0.4  2.1   2.5    .068         NaN   -0.9   0.6
# 680  ...          NaN   0.1  0.1   0.2    .149         NaN   -3.3  -4.1
# 681  ...          NaN   1.3  1.6   2.9    .113         NaN   -0.6   1.1
# 682  ...          NaN   1.1  1.2   2.3    .121         NaN   -0.1   1.1
# 683  ...          NaN   0.2  0.5   0.6    .092         NaN   -1.6   1.0
# 684  ...          NaN   0.1  0.3   0.3    .086         NaN   -2.5   0.7
# 685  ...          NaN   0.0  0.0   0.0  -0.019         NaN   -4.3  -2.7
# 686  ...          NaN   2.6  3.4   6.0    .139         NaN    0.8   2.2
# 687  ...          NaN   1.4  0.6   1.9    .044         NaN    0.8  -3.0
# 688  ...          NaN   2.7  1.3   3.9    .153         NaN    0.3   1.7
# 689  ...          NaN   0.0  0.0   0.0  -0.115         NaN  -10.4  -8.6
# 690  ...          NaN   1.1  0.3   1.4    .084         NaN   -2.4  -1.5
# 691  ...          NaN   1.4  1.0   2.3    .148         NaN   -1.6   0.7
# 692  ...          NaN   1.2  0.6   1.8    .165         NaN   -1.2   0.2
# 693  ...          NaN   0.2  0.3   0.6    .111         NaN   -2.3   1.8
#
#        BPM  VORP
# 0     -3.4  -0.2
# 1     -5.8  -0.1
# 2     -3.6  -0.1
# 3      3.0   2.7
# 4      2.6   1.7
# 5     -7.1  -0.2
# 6     -3.7   0.0
# 7      1.3   1.8
# 8     27.3   0.0
# 9     -8.0  -0.4
# 10     2.9   2.2
# 11    -0.8   0.1
# 12     1.1   1.5
# 13    -5.6  -0.2
# 14     1.5   1.1
# 15    -6.2  -0.3
# 16    -6.4  -0.3
# 17    -3.7   0.0
# 18   -14.0   0.0
# 19    10.4   6.4
# 20    -6.1  -0.3
# 21    -1.1   0.3
# 22     BPM  VORP
# 23    -1.2   0.3
# 24    -0.3   1.0
# 25    -0.8   0.3
# 26     0.1   0.7
# 27    -0.4   0.7
# 28     0.8   1.4
# 29    -4.2  -0.2
# ..     ...   ...
# 664    6.1   4.3
# 665    1.1   1.0
# 666  -19.2   0.0
# 667    0.4   0.9
# 668   -3.1  -0.6
# 669   -1.1   0.0
# 670   -8.3  -0.1
# 671   -1.9   0.0
# 672   -1.1   0.2
# 673    1.2   1.3
# 674    0.6   1.2
# 675    4.9   0.4
# 676    BPM  VORP
# 677   -1.9   0.0
# 678   -1.6   0.1
# 679   -0.3   0.8
# 680   -7.4  -0.1
# 681    0.5   0.8
# 682    1.0   0.7
# 683   -0.6   0.1
# 684   -1.8   0.0
# 685   -7.0   0.0
# 686    2.9   2.6
# 687   -2.2  -0.1
# 688    2.0   1.3
# 689  -19.0   0.0
# 690   -3.9  -0.4
# 691   -0.9   0.2
# 692   -1.0   0.1
# 693   -0.6   0.1
#
# [694 rows x 29 columns]

# %%
#create df from downloaded csv of NBA player stats
#pulled data from Basketball-Reference.com

#df = pd.read_csv('D:\dudad\Documents\Data Science Career Track\Data Wrangling for Capstone 1\player_stats.csv')
#print(df)

# %%
#examine the data
#data is fairly clean directly from the source
df.head()
# Out:
#    Unnamed: 0 Rk        Player Pos Age   Tm   G    MP   PER   TS%  ...   \
# 0           0  1  Alex Abrines  SG  25  OKC  31   588   6.3  .507  ...
# 1           1  2    Quincy Acy  PF  28  PHO  10   123   2.9  .379  ...
# 2           2  3  Jaylen Adams  PG  22  ATL  19   181   9.6  .542  ...
# 3           3  4  Steven Adams   C  25  OKC  64  2167  19.0  .604  ...
# 4           4  5   Bam Adebayo   C  21  MIA  65  1448  17.1  .621  ...
#
#   Unnamed: 19   OWS  DWS    WS   WS/48 Unnamed: 24  OBPM  DBPM   BPM  VORP
# 0         NaN   0.1  0.6   0.7    .053         NaN  -2.4  -1.0  -3.4  -0.2
# 1         NaN  -0.1  0.1  -0.1  -0.020         NaN  -5.7  -0.2  -5.9  -0.1
# 2         NaN   0.1  0.1   0.2    .046         NaN  -1.7  -2.1  -3.7  -0.1
# 3         NaN   4.5  3.3   7.8    .173         NaN   0.9   2.0   2.9   2.7
# 4         NaN   2.6  2.3   4.9    .164         NaN  -0.7   3.3   2.6   1.7
#
# [5 rows x 30 columns]

# %%
#remove unnamed columns from site used for formatting purposes
df = df.drop(columns=['Unnamed: 19', 'Unnamed: 24'])

# %%
#understanding how data was initially interpreted
df.get_dtype_counts()
# Out:
# int64      1
# object    27
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Rk            object
# Player        object
# Pos           object
# Age           object
# Tm            object
# G             object
# MP            object
# PER           object
# TS%           object
# 3PAr          object
# FTr           object
# ORB%          object
# DRB%          object
# TRB%          object
# AST%          object
# STL%          object
# BLK%          object
# TOV%          object
# USG%          object
# OWS           object
# DWS           object
# WS            object
# WS/48         object
# OBPM          object
# DBPM          object
# BPM           object
# VORP          object
# dtype: object

# %%
df['Player'] = df['Player'].astype(str)
print(df.dtypes)
# Out:
# Unnamed: 0     int64
# Rk            object
# Player        object
# Pos           object
# Age           object
# Tm            object
# G             object
# MP            object
# PER           object
# TS%           object
# 3PAr          object
# FTr           object
# ORB%          object
# DRB%          object
# TRB%          object
# AST%          object
# STL%          object
# BLK%          object
# TOV%          object
# USG%          object
# OWS           object
# DWS           object
# WS            object
# WS/48         object
# OBPM          object
# DBPM          object
# BPM           object
# VORP          object
# dtype: object

# %% [markdown]
# ## Breakdown of column names:

# %%
# Rank, Player Name, Position, Age, Team, Games, Minutes Played, Player Efficiency Rating,
# True Shooting Percentage, 3-point attempt rate, Free Throw Attempt Rate, Offensive Rebound Percentage,
# Defensive Rebound Percentage, Total Rebound Percentage, Assist Percentage, Steal Percentage, Block Percentage,
# Turnover Percentage, Usage Percentage, Offensive Win Shares, Defensive Win Shares, Win Shares, Win Shares Per 48 minutes,
# Offensive Box plus/minus, Defensive box plus/minus, Box plus/minus, Value over replacement player
#full definition of all columns can be found at https://www.basketball-reference.com/leagues/NBA_2019_advanced.html
list(df)
# Out:
# ['Unnamed: 0',
#  'Rk',
#  'Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'MP',
#  'PER',
#  'TS%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'USG%',
#  'OWS',
#  'DWS',
#  'WS',
#  'WS/48',
#  'OBPM',
#  'DBPM',
#  'BPM',
#  'VORP']

# %%
# Total missing values for each feature
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# Rk            0
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# MP            0
# PER           0
# TS%           6
# 3PAr          8
# FTr           8
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          6
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# dtype: int64

# %%
#changing data type of Player column in df
df['Player'] = df['Player'].astype(str)

# %%
#check Player column data type
print(print(df['Player']))
# Out:
# 0                Alex Abrines
# 1                  Quincy Acy
# 2                Jaylen Adams
# 3                Steven Adams
# 4                 Bam Adebayo
# 5                   Deng Adel
# 6      DeVaughn Akoon-Purcell
# 7           LaMarcus Aldridge
# 8                Rawle Alkins
# 9               Grayson Allen
# 10              Jarrett Allen
# 11               Kadeem Allen
# 12            Al-Farouq Aminu
# 13            Justin Anderson
# 14              Kyle Anderson
# 15              Ryan Anderson
# 16              Ryan Anderson
# 17              Ryan Anderson
# 18               Ike Anigbogu
# 19      Giannis Antetokounmpo
# 20            Carmelo Anthony
# 21                 OG Anunoby
# 22                     Player
# 23           Ryan Arcidiacono
# 24               Trevor Ariza
# 25               Trevor Ariza
# 26               Trevor Ariza
# 27              D.J. Augustin
# 28              Deandre Ayton
# 29               Dwayne Bacon
#                 ...
# 661         Russell Westbrook
# 662             Derrick White
# 663               Okaro White
# 664          Hassan Whiteside
# 665            Andrew Wiggins
# 666             Alan Williams
# 667             C.J. Williams
# 668        Johnathan Williams
# 669          Kenrich Williams
# 670              Lou Williams
# 671           Marvin Williams
# 672           Robert Williams
# 673             Troy Williams
# 674                    Player
# 675               D.J. Wilson
# 676           Justise Winslow
# 677            Christian Wood
# 678              Delon Wright
# 679              Delon Wright
# 680              Delon Wright
# 681        Guerschon Yabusele
# 682                Nick Young
# 683            Thaddeus Young
# 684                Trae Young
# 685               Cody Zeller
# 686              Tyler Zeller
# 687                Ante Zizic
# 688               Ivica Zubac
# 689               Ivica Zubac
# 690               Ivica Zubac
# Name: Player, Length: 691, dtype: object
# None

# %% [markdown]
# ## Create dataframe for player salary information from Basketball Reference

# %% [markdown]
# ### Pull data directly from website for freshness

# %%
url_salary = 'https://www.basketball-reference.com/contracts/players.html'
html_salary = requests.get(url_salary).content
df_list_salary = pd.read_html(html_salary)
df_salary = df_list_salary[-1]
print(df_salary)
#saves file to csv for offline use
df.to_csv('nba_player_contracts.csv')
df_salary = pd.read_csv('nba_player_contracts.csv')
# Out:
#     Unnamed: 0_level_0              Salary Unnamed: 2_level_0  \
#                     Rk              Player                 Tm
# 0                    1       Stephen Curry                GSW
# 1                    2          Chris Paul                HOU
# 2                    3   Russell Westbrook                OKC
# 3                    4        LeBron James                LAL
# 4                    5       Blake Griffin                DET
# 5                    6      Gordon Hayward                BOS
# 6                    7          Kyle Lowry                TOR
# 7                    8         Paul George                OKC
# 8                    9         Mike Conley                MEM
# 9                   10        James Harden                HOU
# 10                  11        Kevin Durant                GSW
# 11                  12        Paul Millsap                DEN
# 12                  13          Al Horford                BOS
# 13                  14      Damian Lillard                POR
# 14                  15       DeMar DeRozan                SAS
# 15                  16          Chris Bosh                MIA
# 16                  17         Otto Porter                CHI
# 17                  18        Jrue Holiday                NOP
# 18                  19         CJ McCollum                POR
# 19                  20     Carmelo Anthony                ATL
# 20                 NaN              Salary                NaN
# 21                  Rk              Player                 Tm
# 22                  21      Andrew Wiggins                MIN
# 23                  22         Joel Embiid                PHI
# 24                  23        Bradley Beal                WAS
# 25                  24       Anthony Davis                NOP
# 26                  25      Andre Drummond                DET
# 27                  26    Hassan Whiteside                MIA
# 28                  27        Nikola Jokic                DEN
# 29                  28        Steven Adams                OKC
# ..                 ...                 ...                ...
# 572                521         Jodie Meeks                TOR
# 573                522        Tyler Zeller                ATL
# 574                523        John Jenkins                NYK
# 575                524        John Jenkins                NYK
# 576                525        John Jenkins                WAS
# 577                526       Isaiah Canaan                MIL
# 578                527    Cameron Reynolds                MIN
# 579                528         Mitch Creek                BRK
# 580                529   Demetrius Jackson                BOS
# 581                530      Henry Ellenson                NYK
# 582                531         Gary Payton                WAS
# 583                532       Scotty Hopson                OKC
# 584                533        Kobi Simmons                CLE
# 585                534  Shaquille Harrison                PHO
# 586                535        Garlon Green                NOP
# 587                536        Ray Spalding                PHO
# 588                537       Emanuel Terry                PHO
# 589                538     Richard Solomon                OKC
# 590                539       Emanuel Terry                MIA
# 591                540       Stephan Hicks                IND
# 592                NaN              Salary                NaN
# 593                 Rk              Player                 Tm
# 594                541       Chris Chiozza                HOU
# 595                542      Tahjere McCall                BRK
# 596                543       Jordan Sibert                ATL
# 597                544        B.J. Johnson                ATL
# 598                545       Emanuel Terry                DEN
# 599                546       Troy Williams                NOP
# 600                547       Terry Larrier                DAL
# 601                548      Ding Yanyuhang                DAL
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                2018-19            2019-20            2020-21
# 0          $37,457,154        $40,231,758        $43,006,362
# 1          $35,654,150        $38,506,482        $41,358,814
# 2          $35,654,150        $38,178,000        $41,006,000
# 3          $35,654,150        $37,436,858        $39,219,565
# 4          $32,088,932        $34,234,964        $36,595,996
# 5          $31,214,295        $32,700,690        $34,187,085
# 6          $31,200,000        $33,296,296                NaN
# 7          $30,560,700        $33,005,556        $35,450,412
# 8          $30,521,116        $32,511,623        $34,504,132
# 9          $30,431,854        $37,800,000        $40,824,000
# 10         $30,000,000        $31,500,000                NaN
# 11         $29,730,769        $30,500,000                NaN
# 12         $28,928,710        $30,123,015                NaN
# 13         $27,977,689        $29,802,321        $31,626,953
# 14         $27,739,975        $27,739,975        $27,739,975
# 15         $26,837,720                NaN                NaN
# 16         $26,011,913        $27,250,576        $28,489,239
# 17         $25,976,111        $26,131,111        $26,131,111
# 18         $25,759,766        $27,556,959        $29,354,152
# 19         $25,534,253                NaN                NaN
# 20                 NaN                NaN                NaN
# 21             2018-19            2019-20            2020-21
# 22         $25,467,250        $27,270,000        $29,290,000
# 23         $25,467,250        $27,270,000        $29,290,000
# 24         $25,434,263        $27,093,019        $28,751,775
# 25         $25,434,263        $27,093,019        $28,751,775
# 26         $25,434,263        $27,093,019        $28,751,775
# 27         $25,434,263        $27,093,018                NaN
# 28         $24,605,181        $26,573,595        $28,542,009
# 29         $24,157,304        $25,842,697        $27,528,090
# ..                 ...                ...                ...
# 572           $120,904                NaN                NaN
# 573           $105,192                NaN                NaN
# 574            $99,290                NaN                NaN
# 575            $97,635                NaN                NaN
# 576            $97,635                NaN                NaN
# 577            $97,635                NaN                NaN
# 578            $93,164                NaN                NaN
# 579            $93,164                NaN                NaN
# 580            $92,857            $92,857            $92,857
# 581            $84,034                NaN                NaN
# 582            $84,034                NaN                NaN
# 583            $84,034                NaN                NaN
# 584            $74,966                NaN                NaN
# 585            $50,000                NaN                NaN
# 586            $50,000                NaN                NaN
# 587            $46,582                NaN                NaN
# 588            $46,582                NaN                NaN
# 589            $46,582                NaN                NaN
# 590            $46,582                NaN                NaN
# 591            $46,582                NaN                NaN
# 592                NaN                NaN                NaN
# 593            2018-19            2019-20            2020-21
# 594            $46,582                NaN                NaN
# 595            $46,582                NaN                NaN
# 596            $46,582                NaN                NaN
# 597            $46,582                NaN                NaN
# 598            $35,000                NaN                NaN
# 599            $34,183                NaN                NaN
# 600             $6,000                NaN                NaN
# 601             $4,737                NaN                NaN
#
#     Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0  \
#                2021-22            2022-23            2023-24
# 0          $45,780,966                NaN                NaN
# 1          $44,211,146                NaN                NaN
# 2          $43,848,000        $46,662,000                NaN
# 3          $41,002,273                NaN                NaN
# 4          $38,957,028                NaN                NaN
# 5                  NaN                NaN                NaN
# 6                  NaN                NaN                NaN
# 7          $37,895,268                NaN                NaN
# 8                  NaN                NaN                NaN
# 9          $43,848,000        $46,872,000                NaN
# 10                 NaN                NaN                NaN
# 11                 NaN                NaN                NaN
# 12                 NaN                NaN                NaN
# 13                 NaN                NaN                NaN
# 14                 NaN                NaN                NaN
# 15                 NaN                NaN                NaN
# 16                 NaN                NaN                NaN
# 17         $27,020,000                NaN                NaN
# 18                 NaN                NaN                NaN
# 19                 NaN                NaN                NaN
# 20                 NaN                NaN                NaN
# 21             2021-22            2022-23            2023-24
# 22         $31,310,000        $33,330,000                NaN
# 23         $31,310,000        $33,330,000                NaN
# 24                 NaN                NaN                NaN
# 25                 NaN                NaN                NaN
# 26                 NaN                NaN                NaN
# 27                 NaN                NaN                NaN
# 28         $30,510,423        $32,478,837                NaN
# 29                 NaN                NaN                NaN
# ..                 ...                ...                ...
# 572                NaN                NaN                NaN
# 573                NaN                NaN                NaN
# 574                NaN                NaN                NaN
# 575                NaN                NaN                NaN
# 576                NaN                NaN                NaN
# 577                NaN                NaN                NaN
# 578                NaN                NaN                NaN
# 579                NaN                NaN                NaN
# 580            $92,857            $92,857                NaN
# 581                NaN                NaN                NaN
# 582                NaN                NaN                NaN
# 583                NaN                NaN                NaN
# 584                NaN                NaN                NaN
# 585                NaN                NaN                NaN
# 586                NaN                NaN                NaN
# 587                NaN                NaN                NaN
# 588                NaN                NaN                NaN
# 589                NaN                NaN                NaN
# 590                NaN                NaN                NaN
# 591                NaN                NaN                NaN
# 592                NaN                NaN                NaN
# 593            2021-22            2022-23            2023-24
# 594                NaN                NaN                NaN
# 595                NaN                NaN                NaN
# 596                NaN                NaN                NaN
# 597                NaN                NaN                NaN
# 598                NaN                NaN                NaN
# 599                NaN                NaN                NaN
# 600                NaN                NaN                NaN
# 601                NaN                NaN                NaN
#
#     Unnamed: 9_level_0 Unnamed: 10_level_0
#           Signed Using          Guaranteed
# 0          Bird Rights        $166,476,240
# 1                  NaN        $159,730,592
# 2          Bird Rights        $158,686,150
# 3                  NaN        $113,310,573
# 4          Bird Rights        $102,919,892
# 5            Cap space         $63,914,985
# 6          Bird Rights         $64,496,296
# 7       Maximum Salary         $99,016,668
# 8            Cap Space         $85,459,122
# 9          Bird Rights        $152,903,854
# 10                 NaN         $30,000,000
# 11           Cap space         $29,730,769
# 12           Cap Space         $28,928,710
# 13      1st Round Pick         $89,406,963
# 14           Cap Space         $55,479,950
# 15                 NaN         $26,837,720
# 16         Bird Rights         $53,262,489
# 17         Bird Rights         $78,238,333
# 18      1st Round Pick         $82,670,877
# 19                 NaN         $25,534,253
# 20                 NaN                 NaN
# 21        Signed Using          Guaranteed
# 22      1st Round Pick        $146,667,250
# 23      1st Round Pick         $25,467,250
# 24           Cap Space         $81,279,057
# 25      1st Round Pick         $52,527,282
# 26           Cap Space         $52,527,282
# 27           Cap Space         $25,434,263
# 28                 NaN        $142,710,045
# 29      1st Round Pick         $77,528,091
# ..                 ...                 ...
# 572                NaN            $120,904
# 573    10-Day Contract            $105,192
# 574                NaN            $196,925
# 575                NaN            $196,925
# 576                NaN             $97,635
# 577                NaN             $97,635
# 578    10-Day Contract             $93,164
# 579                NaN             $93,164
# 580                NaN            $557,142
# 581                NaN            $425,865
# 582                NaN             $84,034
# 583                NaN             $84,034
# 584                NaN             $74,966
# 585                NaN             $50,000
# 586                NaN             $50,000
# 587                NaN            $231,328
# 588                NaN             $46,582
# 589                NaN             $46,582
# 590                NaN             $46,582
# 591                NaN             $46,582
# 592                NaN                 NaN
# 593       Signed Using          Guaranteed
# 594                NaN             $46,582
# 595                NaN             $46,582
# 596                NaN             $46,582
# 597    10-Day Contract             $46,582
# 598                NaN             $35,000
# 599                NaN             $34,183
# 600                NaN              $6,000
# 601                NaN              $4,737
#
# [602 rows x 11 columns]

# %%
#remove first row from table as this is a title row, not column names
df_salary.columns = df_salary.columns.droplevel(0)
print(df_salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-b066158c3605> in <module>
#       1 #remove first row from table as this is a title row, not column names
# ----> 2 df_salary.columns = df_salary.columns.droplevel(-1)
#       3 print(df_salary)
#
# AttributeError: 'Index' object has no attribute 'droplevel'

# %%
#remove rows that are utilized as continued header row
df.drop(df.index[22], inplace = True)
print(df)
# Out:
#      Unnamed: 0   Rk                  Player  Pos  Age   Tm   G    MP   PER  \
# 0             0    1            Alex Abrines   SG   25  OKC  31   588   6.3
# 1             1    2              Quincy Acy   PF   28  PHO  10   123   2.9
# 2             2    3            Jaylen Adams   PG   22  ATL  19   181   9.6
# 3             3    4            Steven Adams    C   25  OKC  64  2167  19.0
# 4             4    5             Bam Adebayo    C   21  MIA  65  1448  17.1
# 5             5    6               Deng Adel   SF   21  CLE  12   158   2.2
# 6             6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.3
# 7             7    8       LaMarcus Aldridge    C   33  SAS  65  2132  22.5
# 8             8    9            Rawle Alkins   SG   21  CHI   3     6  37.9
# 9             9   10           Grayson Allen   SG   23  UTA  30   290   4.1
# 10           10   11           Jarrett Allen    C   20  BRK  66  1760  19.0
# 11           11   12            Kadeem Allen   SG   26  NYK  10   225  17.2
# 12           12   13         Al-Farouq Aminu   PF   28  POR  66  1911  13.2
# 13           13   14         Justin Anderson   SF   25  ATL  36   277   7.7
# 14           14   15           Kyle Anderson   SF   25  MEM  43  1281  12.9
# 15           15   16           Ryan Anderson   PF   30  TOT  19   294   5.1
# 16           16   16           Ryan Anderson   PF   30  PHO  15   278   4.6
# 17           17   16           Ryan Anderson   PF   30  MIA   4    16  13.4
# 18           18   17            Ike Anigbogu    C   20  IND   3     6  -6.0
# 19           19   18   Giannis Antetokounmpo   PF   24  MIL  61  2012  30.2
# 20           20   19         Carmelo Anthony   PF   34  HOU  10   294  11.0
# 21           21   20              OG Anunoby   SF   21  TOR  55  1121   9.7
# 23           23   21        Ryan Arcidiacono   PG   24  CHI  66  1624  10.7
# 24           24   22            Trevor Ariza   SF   33  TOT  62  2188  12.2
# 25           25   22            Trevor Ariza   SF   33  PHO  26   884  10.5
# 26           26   22            Trevor Ariza   SF   33  WAS  36  1304  13.4
# 27           27   23           D.J. Augustin   PG   31  ORL  66  1819  15.6
# 28           28   24           Deandre Ayton    C   20  PHO  61  1886  21.0
# 29           29   25            Dwayne Bacon   SG   23  CHO  27   309  11.0
# 30           30   26           Marvin Bagley   PF   19  SAC  47  1165  18.2
# ..          ...  ...                     ...  ...  ...  ...  ..   ...   ...
# 661         661  488       Russell Westbrook   PG   30  OKC  58  2075  20.8
# 662         662  489           Derrick White   PG   24  SAS  51  1307  15.3
# 663         663  490             Okaro White   PF   26  WAS   3     6  -4.5
# 664         664  491        Hassan Whiteside    C   29  MIA  56  1405  22.6
# 665         665  492          Andrew Wiggins   SF   23  MIN  59  2053  11.9
# 666         666  493           Alan Williams   PF   26  BRK   3    17  25.0
# 667         667  494           C.J. Williams   SG   28  MIN   9    67   2.1
# 668         668  495      Johnathan Williams    C   23  LAL   9   133  13.6
# 669         669  496        Kenrich Williams   SF   24  NOP  32   670   9.8
# 670         670  497            Lou Williams   SG   32  LAC  61  1620  21.7
# 671         671  498         Marvin Williams   PF   32  CHO  65  1874  13.0
# 672         672  499         Robert Williams    C   21  BOS  26   221  19.8
# 673         673  500           Troy Williams   SF   24  SAC  18   286  11.1
# 674         674   Rk                  Player  Pos  Age   Tm   G    MP   PER
# 675         675  501             D.J. Wilson   PF   22  MIL  34   575   9.8
# 676         676  502         Justise Winslow   PF   22  MIA  58  1729  13.1
# 677         677  503          Christian Wood   PF   23  MIL  13    62  17.3
# 678         678  504            Delon Wright   PG   26  TOT  60  1205  14.4
# 679         679  504            Delon Wright   PG   26  TOR  49   897  14.6
# 680         680  504            Delon Wright   PG   26  MEM  11   308  13.7
# 681         681  505      Guerschon Yabusele   PF   23  BOS  33   178  13.1
# 682         682  506              Nick Young   SG   33  DEN   4    37   2.4
# 683         683  507          Thaddeus Young   PF   30  IND  66  2016  16.6
# 684         684  508              Trae Young   PG   20  ATL  67  2061  15.9
# 685         685  509             Cody Zeller    C   26  CHO  49  1243  17.2
# 686         686  510            Tyler Zeller  F-C   29  ATL   1     7  -1.0
# 687         687  511              Ante Zizic    C   22  CLE  46   790  15.7
# 688         688  512             Ivica Zubac    C   21  TOT  44   731  18.8
# 689         689  512             Ivica Zubac    C   21  LAL  33   516  19.6
# 690         690  512             Ivica Zubac    C   21  LAC  11   215  16.8
#
#       TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 0    .507  ...    7.9  12.2   0.1  0.6   0.7    .053   -2.4  -1.0   -3.4  -0.2
# 1    .379  ...   15.2   9.2  -0.1  0.1  -0.1  -0.020   -5.7  -0.2   -5.9  -0.1
# 2    .542  ...   19.7  13.7   0.1  0.1   0.2    .046   -1.7  -2.1   -3.7  -0.1
# 3    .604  ...   12.6  16.4   4.5  3.3   7.8    .173    0.9   2.0    2.9   2.7
# 4    .621  ...   17.8  15.3   2.6  2.3   4.9    .164   -0.7   3.3    2.6   1.7
# 5    .405  ...   13.9   9.9  -0.2  0.0  -0.2  -0.065   -5.4  -1.7   -7.2  -0.2
# 6    .322  ...   15.5  24.8  -0.1  0.0   0.0  -0.046   -4.3   0.6   -3.7   0.0
# 7    .572  ...    9.2  27.2   4.9  2.0   6.9    .156    1.1   0.1    1.2   1.7
# 8    .375  ...    0.0  29.2   0.0  0.0   0.0    .354   20.0   7.3   27.4   0.0
# 9    .451  ...   11.6  21.6  -0.4  0.2  -0.2  -0.036   -4.7  -3.4   -8.1  -0.4
# 10   .630  ...   12.7  16.2   3.8  2.6   6.5    .176   -0.4   3.0    2.7   2.1
# 11   .578  ...   11.2  18.5   0.5  0.1   0.6    .137    1.2  -2.0   -0.8   0.1
# 12   .578  ...    9.8  13.1   2.7  2.2   4.9    .124    0.2   0.9    1.1   1.5
# 13   .459  ...   13.0  17.0  -0.2  0.2   0.0  -0.008   -4.7  -0.9   -5.6  -0.2
# 14   .569  ...   16.0  12.7   0.8  2.0   2.9    .107   -2.1   3.5    1.5   1.1
# 15   .437  ...   15.3  12.4  -0.2  0.0  -0.2  -0.029   -4.1  -2.1   -6.2  -0.3
# 16   .423  ...   15.4  12.1  -0.2  0.0  -0.2  -0.036   -4.4  -2.0   -6.4  -0.3
# 17   .595  ...   14.5  18.4   0.0  0.0   0.0    .101    1.3  -3.9   -2.6   0.0
# 18   .000  ...   25.0  29.2  -0.1  0.0  -0.1  -0.475  -22.6   8.6  -14.0   0.0
# 19   .640  ...   15.5  31.9   7.1  4.8  11.9    .283    5.3   5.1   10.4   6.3
# 20   .513  ...    5.8  20.4   0.1  0.2   0.3    .041   -3.0  -3.2   -6.2  -0.3
# 21   .538  ...    9.6  15.1   0.4  1.3   1.6    .070   -1.2  -0.1   -1.3   0.2
# 23   .588  ...   13.6  10.5   2.1  0.9   3.0    .088   -0.3  -0.8   -1.1   0.4
# 24   .537  ...   11.6  16.6   1.4  1.2   2.5    .056    0.1  -0.3   -0.2   1.0
# 25   .525  ...   13.7  13.8   0.2  0.5   0.7    .037   -1.2   0.4   -0.8   0.3
# 26   .543  ...   10.6  18.4   1.2  0.7   1.8    .068    0.9  -0.7    0.2   0.7
# 27   .631  ...   14.4  16.8   4.2  1.3   5.5    .145    1.8  -2.1   -0.3   0.8
# 28   .616  ...   11.2  21.0   4.1  1.5   5.6    .142    0.5   0.3    0.9   1.4
# 29   .610  ...   11.3  15.9   0.3  0.1   0.5    .071   -1.8  -2.5   -4.3  -0.2
# 30   .566  ...   11.7  23.1   1.4  1.3   2.7    .112   -1.4  -0.1   -1.4   0.2
# ..    ...  ...    ...   ...   ...  ...   ...     ...    ...   ...    ...   ...
# 661  .499  ...   16.8  31.5   0.9  4.0   4.9    .114    2.0   3.9    6.0   4.2
# 662  .572  ...   14.6  17.3   1.5  1.4   2.9    .106    0.2   1.0    1.2   1.1
# 663  .000  ...    0.0  14.1   0.0  0.0   0.0  -0.251  -11.0  -8.2  -19.2   0.0
# 664  .549  ...   11.6  22.6   1.5  3.2   4.8    .163   -2.6   3.0    0.4   0.9
# 665  .483  ...    9.0  24.1  -0.6  1.1   0.5    .012   -2.0  -1.2   -3.2  -0.6
# 666  .512  ...    9.3  26.7   0.0  0.0   0.1    .199   -1.9   0.7   -1.2   0.0
# 667  .441  ...   19.0  13.1  -0.1  0.0  -0.1  -0.055   -5.1  -3.2   -8.3  -0.1
# 668  .557  ...    4.4  14.4   0.2  0.1   0.3    .126   -1.4  -0.6   -1.9   0.0
# 669  .504  ...   11.6  12.7   0.2  0.6   0.8    .057   -1.2   0.3   -0.9   0.2
# 670  .555  ...   11.6  32.7   3.4  1.0   4.4    .130    3.5  -2.5    1.0   1.2
# 671  .558  ...    6.0  15.0   2.1  1.7   3.8    .097    0.3   0.4    0.6   1.2
# 672  .740  ...   16.0  11.0   0.5  0.5   1.0    .213   -1.8   6.7    5.0   0.4
# 673  .550  ...    7.9  14.7   0.2  0.3   0.5    .080   -2.0   0.1   -1.9   0.0
# 674   TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 675  .508  ...   11.2  13.7   0.1  1.0   1.0    .088   -2.9   1.4   -1.6   0.1
# 676  .515  ...   15.0  20.6   0.5  2.1   2.6    .073   -0.8   0.7   -0.1   0.8
# 677  .585  ...    8.7  23.5   0.1  0.1   0.2    .150   -3.3  -4.1   -7.3  -0.1
# 678  .521  ...   10.4  17.6   1.2  1.6   2.8    .112   -0.6   1.2    0.6   0.8
# 679  .527  ...   10.4  17.0   1.1  1.2   2.3    .121   -0.1   1.2    1.1   0.7
# 680  .505  ...   10.6  19.3   0.1  0.4   0.5    .084   -2.0   1.1   -0.9   0.1
# 681  .530  ...   15.6  18.7   0.1  0.3   0.4    .098   -2.0   0.9   -1.1   0.0
# 682  .500  ...   18.2  12.6   0.0  0.0   0.0  -0.019   -4.3  -2.7   -7.0   0.0
# 683  .568  ...   11.2  17.9   2.7  3.3   6.0    .143    0.9   2.2    3.1   2.6
# 684  .534  ...   18.7  28.0   1.4  0.6   1.9    .045    1.0  -2.9   -2.0   0.0
# 685  .611  ...   13.2  16.2   2.7  1.3   4.0    .153    0.4   1.7    2.1   1.3
# 686  .000  ...    0.0  11.7   0.0  0.0   0.0  -0.115  -10.4  -8.6  -19.0   0.0
# 687  .579  ...   13.2  18.0   1.1  0.3   1.4    .083   -2.4  -1.4   -3.8  -0.4
# 688  .601  ...   13.0  20.7   1.3  0.9   2.2    .147   -1.6   0.7   -0.9   0.2
# 689  .633  ...   12.9  20.5   1.2  0.6   1.8    .165   -1.2   0.2   -1.0   0.1
# 690  .526  ...   13.1  21.0   0.1  0.3   0.5    .105   -2.7   2.0   -0.7   0.1
#
# [690 rows x 28 columns]

# %%
#create df_salary from nba player salaries data from Basketball Reference
#df_salary = pd.read_csv('D:\dudad\Documents\Data Science Career Track\Data Wrangling for Capstone 1\player_salary.csv')
#print(df_salary)

# %%
df_salary.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Rk        Player Pos Age   Tm   G    MP   PER  \
# 0           0             0  1  Alex Abrines  SG  25  OKC  31   588   6.3
# 1           1             1  2    Quincy Acy  PF  28  PHO  10   123   2.9
# 2           2             2  3  Jaylen Adams  PG  22  ATL  19   181   9.6
# 3           3             3  4  Steven Adams   C  25  OKC  64  2167  19.0
# 4           4             4  5   Bam Adebayo   C  21  MIA  65  1448  17.1
#
#    ...   TOV%  USG%   OWS  DWS    WS   WS/48  OBPM  DBPM   BPM  VORP
# 0  ...    7.9  12.2   0.1  0.6   0.7    .053  -2.4  -1.0  -3.4  -0.2
# 1  ...   15.2   9.2  -0.1  0.1  -0.1  -0.020  -5.7  -0.2  -5.9  -0.1
# 2  ...   19.7  13.7   0.1  0.1   0.2    .046  -1.7  -2.1  -3.7  -0.1
# 3  ...   12.6  16.4   4.5  3.3   7.8    .173   0.9   2.0   2.9   2.7
# 4  ...   17.8  15.3   2.6  2.3   4.9    .164  -0.7   3.3   2.6   1.7
#
# [5 rows x 29 columns]

# %%
# Total missing values for each feature
print(df_salary.isnull().sum())
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Rk              0
# Player          0
# Pos             0
# Age             0
# Tm              0
# G               0
# MP              0
# PER             0
# TS%             6
# 3PAr            8
# FTr             8
# ORB%            0
# DRB%            0
# TRB%            0
# AST%            0
# STL%            0
# BLK%            0
# TOV%            6
# USG%            0
# OWS             0
# DWS             0
# WS              0
# WS/48           0
# OBPM            0
# DBPM            0
# BPM             0
# VORP            0
# dtype: int64

# %%
cols_stats = list(df.columns)

# %%
print(cols_stats)
# Out:
# ['Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']

# %%
cols_salary = list(df_salary.columns)

# %%
print(cols_salary)
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']

# %% [markdown]
# ## Converting columns to correct datatype for future analysis

# %%
#df column data is not correct type
print(type(df['WS']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#found another header row at row 48, removing
df.drop(df.index[48], inplace = True)
print(df)
# Out:
#      Unnamed: 0   Rk                  Player  Pos  Age   Tm   G    MP   PER  \
# 0             0    1            Alex Abrines   SG   25  OKC  31   588   6.3
# 1             1    2              Quincy Acy   PF   28  PHO  10   123   2.9
# 2             2    3            Jaylen Adams   PG   22  ATL  19   181   9.6
# 3             3    4            Steven Adams    C   25  OKC  64  2167  19.0
# 4             4    5             Bam Adebayo    C   21  MIA  65  1448  17.1
# 5             5    6               Deng Adel   SF   21  CLE  12   158   2.2
# 6             6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.3
# 7             7    8       LaMarcus Aldridge    C   33  SAS  65  2132  22.5
# 8             8    9            Rawle Alkins   SG   21  CHI   3     6  37.9
# 9             9   10           Grayson Allen   SG   23  UTA  30   290   4.1
# 10           10   11           Jarrett Allen    C   20  BRK  66  1760  19.0
# 11           11   12            Kadeem Allen   SG   26  NYK  10   225  17.2
# 12           12   13         Al-Farouq Aminu   PF   28  POR  66  1911  13.2
# 13           13   14         Justin Anderson   SF   25  ATL  36   277   7.7
# 14           14   15           Kyle Anderson   SF   25  MEM  43  1281  12.9
# 15           15   16           Ryan Anderson   PF   30  TOT  19   294   5.1
# 16           16   16           Ryan Anderson   PF   30  PHO  15   278   4.6
# 17           17   16           Ryan Anderson   PF   30  MIA   4    16  13.4
# 18           18   17            Ike Anigbogu    C   20  IND   3     6  -6.0
# 19           19   18   Giannis Antetokounmpo   PF   24  MIL  61  2012  30.2
# 20           20   19         Carmelo Anthony   PF   34  HOU  10   294  11.0
# 21           21   20              OG Anunoby   SF   21  TOR  55  1121   9.7
# 23           23   21        Ryan Arcidiacono   PG   24  CHI  66  1624  10.7
# 24           24   22            Trevor Ariza   SF   33  TOT  62  2188  12.2
# 25           25   22            Trevor Ariza   SF   33  PHO  26   884  10.5
# 26           26   22            Trevor Ariza   SF   33  WAS  36  1304  13.4
# 27           27   23           D.J. Augustin   PG   31  ORL  66  1819  15.6
# 28           28   24           Deandre Ayton    C   20  PHO  61  1886  21.0
# 29           29   25            Dwayne Bacon   SG   23  CHO  27   309  11.0
# 30           30   26           Marvin Bagley   PF   19  SAC  47  1165  18.2
# ..          ...  ...                     ...  ...  ...  ...  ..   ...   ...
# 661         661  488       Russell Westbrook   PG   30  OKC  58  2075  20.8
# 662         662  489           Derrick White   PG   24  SAS  51  1307  15.3
# 663         663  490             Okaro White   PF   26  WAS   3     6  -4.5
# 664         664  491        Hassan Whiteside    C   29  MIA  56  1405  22.6
# 665         665  492          Andrew Wiggins   SF   23  MIN  59  2053  11.9
# 666         666  493           Alan Williams   PF   26  BRK   3    17  25.0
# 667         667  494           C.J. Williams   SG   28  MIN   9    67   2.1
# 668         668  495      Johnathan Williams    C   23  LAL   9   133  13.6
# 669         669  496        Kenrich Williams   SF   24  NOP  32   670   9.8
# 670         670  497            Lou Williams   SG   32  LAC  61  1620  21.7
# 671         671  498         Marvin Williams   PF   32  CHO  65  1874  13.0
# 672         672  499         Robert Williams    C   21  BOS  26   221  19.8
# 673         673  500           Troy Williams   SF   24  SAC  18   286  11.1
# 674         674   Rk                  Player  Pos  Age   Tm   G    MP   PER
# 675         675  501             D.J. Wilson   PF   22  MIL  34   575   9.8
# 676         676  502         Justise Winslow   PF   22  MIA  58  1729  13.1
# 677         677  503          Christian Wood   PF   23  MIL  13    62  17.3
# 678         678  504            Delon Wright   PG   26  TOT  60  1205  14.4
# 679         679  504            Delon Wright   PG   26  TOR  49   897  14.6
# 680         680  504            Delon Wright   PG   26  MEM  11   308  13.7
# 681         681  505      Guerschon Yabusele   PF   23  BOS  33   178  13.1
# 682         682  506              Nick Young   SG   33  DEN   4    37   2.4
# 683         683  507          Thaddeus Young   PF   30  IND  66  2016  16.6
# 684         684  508              Trae Young   PG   20  ATL  67  2061  15.9
# 685         685  509             Cody Zeller    C   26  CHO  49  1243  17.2
# 686         686  510            Tyler Zeller  F-C   29  ATL   1     7  -1.0
# 687         687  511              Ante Zizic    C   22  CLE  46   790  15.7
# 688         688  512             Ivica Zubac    C   21  TOT  44   731  18.8
# 689         689  512             Ivica Zubac    C   21  LAL  33   516  19.6
# 690         690  512             Ivica Zubac    C   21  LAC  11   215  16.8
#
#       TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 0    .507  ...    7.9  12.2   0.1  0.6   0.7    .053   -2.4  -1.0   -3.4  -0.2
# 1    .379  ...   15.2   9.2  -0.1  0.1  -0.1  -0.020   -5.7  -0.2   -5.9  -0.1
# 2    .542  ...   19.7  13.7   0.1  0.1   0.2    .046   -1.7  -2.1   -3.7  -0.1
# 3    .604  ...   12.6  16.4   4.5  3.3   7.8    .173    0.9   2.0    2.9   2.7
# 4    .621  ...   17.8  15.3   2.6  2.3   4.9    .164   -0.7   3.3    2.6   1.7
# 5    .405  ...   13.9   9.9  -0.2  0.0  -0.2  -0.065   -5.4  -1.7   -7.2  -0.2
# 6    .322  ...   15.5  24.8  -0.1  0.0   0.0  -0.046   -4.3   0.6   -3.7   0.0
# 7    .572  ...    9.2  27.2   4.9  2.0   6.9    .156    1.1   0.1    1.2   1.7
# 8    .375  ...    0.0  29.2   0.0  0.0   0.0    .354   20.0   7.3   27.4   0.0
# 9    .451  ...   11.6  21.6  -0.4  0.2  -0.2  -0.036   -4.7  -3.4   -8.1  -0.4
# 10   .630  ...   12.7  16.2   3.8  2.6   6.5    .176   -0.4   3.0    2.7   2.1
# 11   .578  ...   11.2  18.5   0.5  0.1   0.6    .137    1.2  -2.0   -0.8   0.1
# 12   .578  ...    9.8  13.1   2.7  2.2   4.9    .124    0.2   0.9    1.1   1.5
# 13   .459  ...   13.0  17.0  -0.2  0.2   0.0  -0.008   -4.7  -0.9   -5.6  -0.2
# 14   .569  ...   16.0  12.7   0.8  2.0   2.9    .107   -2.1   3.5    1.5   1.1
# 15   .437  ...   15.3  12.4  -0.2  0.0  -0.2  -0.029   -4.1  -2.1   -6.2  -0.3
# 16   .423  ...   15.4  12.1  -0.2  0.0  -0.2  -0.036   -4.4  -2.0   -6.4  -0.3
# 17   .595  ...   14.5  18.4   0.0  0.0   0.0    .101    1.3  -3.9   -2.6   0.0
# 18   .000  ...   25.0  29.2  -0.1  0.0  -0.1  -0.475  -22.6   8.6  -14.0   0.0
# 19   .640  ...   15.5  31.9   7.1  4.8  11.9    .283    5.3   5.1   10.4   6.3
# 20   .513  ...    5.8  20.4   0.1  0.2   0.3    .041   -3.0  -3.2   -6.2  -0.3
# 21   .538  ...    9.6  15.1   0.4  1.3   1.6    .070   -1.2  -0.1   -1.3   0.2
# 23   .588  ...   13.6  10.5   2.1  0.9   3.0    .088   -0.3  -0.8   -1.1   0.4
# 24   .537  ...   11.6  16.6   1.4  1.2   2.5    .056    0.1  -0.3   -0.2   1.0
# 25   .525  ...   13.7  13.8   0.2  0.5   0.7    .037   -1.2   0.4   -0.8   0.3
# 26   .543  ...   10.6  18.4   1.2  0.7   1.8    .068    0.9  -0.7    0.2   0.7
# 27   .631  ...   14.4  16.8   4.2  1.3   5.5    .145    1.8  -2.1   -0.3   0.8
# 28   .616  ...   11.2  21.0   4.1  1.5   5.6    .142    0.5   0.3    0.9   1.4
# 29   .610  ...   11.3  15.9   0.3  0.1   0.5    .071   -1.8  -2.5   -4.3  -0.2
# 30   .566  ...   11.7  23.1   1.4  1.3   2.7    .112   -1.4  -0.1   -1.4   0.2
# ..    ...  ...    ...   ...   ...  ...   ...     ...    ...   ...    ...   ...
# 661  .499  ...   16.8  31.5   0.9  4.0   4.9    .114    2.0   3.9    6.0   4.2
# 662  .572  ...   14.6  17.3   1.5  1.4   2.9    .106    0.2   1.0    1.2   1.1
# 663  .000  ...    0.0  14.1   0.0  0.0   0.0  -0.251  -11.0  -8.2  -19.2   0.0
# 664  .549  ...   11.6  22.6   1.5  3.2   4.8    .163   -2.6   3.0    0.4   0.9
# 665  .483  ...    9.0  24.1  -0.6  1.1   0.5    .012   -2.0  -1.2   -3.2  -0.6
# 666  .512  ...    9.3  26.7   0.0  0.0   0.1    .199   -1.9   0.7   -1.2   0.0
# 667  .441  ...   19.0  13.1  -0.1  0.0  -0.1  -0.055   -5.1  -3.2   -8.3  -0.1
# 668  .557  ...    4.4  14.4   0.2  0.1   0.3    .126   -1.4  -0.6   -1.9   0.0
# 669  .504  ...   11.6  12.7   0.2  0.6   0.8    .057   -1.2   0.3   -0.9   0.2
# 670  .555  ...   11.6  32.7   3.4  1.0   4.4    .130    3.5  -2.5    1.0   1.2
# 671  .558  ...    6.0  15.0   2.1  1.7   3.8    .097    0.3   0.4    0.6   1.2
# 672  .740  ...   16.0  11.0   0.5  0.5   1.0    .213   -1.8   6.7    5.0   0.4
# 673  .550  ...    7.9  14.7   0.2  0.3   0.5    .080   -2.0   0.1   -1.9   0.0
# 674   TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 675  .508  ...   11.2  13.7   0.1  1.0   1.0    .088   -2.9   1.4   -1.6   0.1
# 676  .515  ...   15.0  20.6   0.5  2.1   2.6    .073   -0.8   0.7   -0.1   0.8
# 677  .585  ...    8.7  23.5   0.1  0.1   0.2    .150   -3.3  -4.1   -7.3  -0.1
# 678  .521  ...   10.4  17.6   1.2  1.6   2.8    .112   -0.6   1.2    0.6   0.8
# 679  .527  ...   10.4  17.0   1.1  1.2   2.3    .121   -0.1   1.2    1.1   0.7
# 680  .505  ...   10.6  19.3   0.1  0.4   0.5    .084   -2.0   1.1   -0.9   0.1
# 681  .530  ...   15.6  18.7   0.1  0.3   0.4    .098   -2.0   0.9   -1.1   0.0
# 682  .500  ...   18.2  12.6   0.0  0.0   0.0  -0.019   -4.3  -2.7   -7.0   0.0
# 683  .568  ...   11.2  17.9   2.7  3.3   6.0    .143    0.9   2.2    3.1   2.6
# 684  .534  ...   18.7  28.0   1.4  0.6   1.9    .045    1.0  -2.9   -2.0   0.0
# 685  .611  ...   13.2  16.2   2.7  1.3   4.0    .153    0.4   1.7    2.1   1.3
# 686  .000  ...    0.0  11.7   0.0  0.0   0.0  -0.115  -10.4  -8.6  -19.0   0.0
# 687  .579  ...   13.2  18.0   1.1  0.3   1.4    .083   -2.4  -1.4   -3.8  -0.4
# 688  .601  ...   13.0  20.7   1.3  0.9   2.2    .147   -1.6   0.7   -0.9   0.2
# 689  .633  ...   12.9  20.5   1.2  0.6   1.8    .165   -1.2   0.2   -1.0   0.1
# 690  .526  ...   13.1  21.0   0.1  0.3   0.5    .105   -2.7   2.0   -0.7   0.1
#
# [689 rows x 28 columns]

# %%
#found another header row at row 70, removing
df.drop(df.index[70], inplace = True)
print(df)
# Out:
#      Unnamed: 0   Rk                  Player  Pos  Age   Tm   G    MP   PER  \
# 0             0    1            Alex Abrines   SG   25  OKC  31   588   6.3
# 1             1    2              Quincy Acy   PF   28  PHO  10   123   2.9
# 2             2    3            Jaylen Adams   PG   22  ATL  19   181   9.6
# 3             3    4            Steven Adams    C   25  OKC  64  2167  19.0
# 4             4    5             Bam Adebayo    C   21  MIA  65  1448  17.1
# 5             5    6               Deng Adel   SF   21  CLE  12   158   2.2
# 6             6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.3
# 7             7    8       LaMarcus Aldridge    C   33  SAS  65  2132  22.5
# 8             8    9            Rawle Alkins   SG   21  CHI   3     6  37.9
# 9             9   10           Grayson Allen   SG   23  UTA  30   290   4.1
# 10           10   11           Jarrett Allen    C   20  BRK  66  1760  19.0
# 11           11   12            Kadeem Allen   SG   26  NYK  10   225  17.2
# 12           12   13         Al-Farouq Aminu   PF   28  POR  66  1911  13.2
# 13           13   14         Justin Anderson   SF   25  ATL  36   277   7.7
# 14           14   15           Kyle Anderson   SF   25  MEM  43  1281  12.9
# 15           15   16           Ryan Anderson   PF   30  TOT  19   294   5.1
# 16           16   16           Ryan Anderson   PF   30  PHO  15   278   4.6
# 17           17   16           Ryan Anderson   PF   30  MIA   4    16  13.4
# 18           18   17            Ike Anigbogu    C   20  IND   3     6  -6.0
# 19           19   18   Giannis Antetokounmpo   PF   24  MIL  61  2012  30.2
# 20           20   19         Carmelo Anthony   PF   34  HOU  10   294  11.0
# 21           21   20              OG Anunoby   SF   21  TOR  55  1121   9.7
# 23           23   21        Ryan Arcidiacono   PG   24  CHI  66  1624  10.7
# 24           24   22            Trevor Ariza   SF   33  TOT  62  2188  12.2
# 25           25   22            Trevor Ariza   SF   33  PHO  26   884  10.5
# 26           26   22            Trevor Ariza   SF   33  WAS  36  1304  13.4
# 27           27   23           D.J. Augustin   PG   31  ORL  66  1819  15.6
# 28           28   24           Deandre Ayton    C   20  PHO  61  1886  21.0
# 29           29   25            Dwayne Bacon   SG   23  CHO  27   309  11.0
# 30           30   26           Marvin Bagley   PF   19  SAC  47  1165  18.2
# ..          ...  ...                     ...  ...  ...  ...  ..   ...   ...
# 661         661  488       Russell Westbrook   PG   30  OKC  58  2075  20.8
# 662         662  489           Derrick White   PG   24  SAS  51  1307  15.3
# 663         663  490             Okaro White   PF   26  WAS   3     6  -4.5
# 664         664  491        Hassan Whiteside    C   29  MIA  56  1405  22.6
# 665         665  492          Andrew Wiggins   SF   23  MIN  59  2053  11.9
# 666         666  493           Alan Williams   PF   26  BRK   3    17  25.0
# 667         667  494           C.J. Williams   SG   28  MIN   9    67   2.1
# 668         668  495      Johnathan Williams    C   23  LAL   9   133  13.6
# 669         669  496        Kenrich Williams   SF   24  NOP  32   670   9.8
# 670         670  497            Lou Williams   SG   32  LAC  61  1620  21.7
# 671         671  498         Marvin Williams   PF   32  CHO  65  1874  13.0
# 672         672  499         Robert Williams    C   21  BOS  26   221  19.8
# 673         673  500           Troy Williams   SF   24  SAC  18   286  11.1
# 674         674   Rk                  Player  Pos  Age   Tm   G    MP   PER
# 675         675  501             D.J. Wilson   PF   22  MIL  34   575   9.8
# 676         676  502         Justise Winslow   PF   22  MIA  58  1729  13.1
# 677         677  503          Christian Wood   PF   23  MIL  13    62  17.3
# 678         678  504            Delon Wright   PG   26  TOT  60  1205  14.4
# 679         679  504            Delon Wright   PG   26  TOR  49   897  14.6
# 680         680  504            Delon Wright   PG   26  MEM  11   308  13.7
# 681         681  505      Guerschon Yabusele   PF   23  BOS  33   178  13.1
# 682         682  506              Nick Young   SG   33  DEN   4    37   2.4
# 683         683  507          Thaddeus Young   PF   30  IND  66  2016  16.6
# 684         684  508              Trae Young   PG   20  ATL  67  2061  15.9
# 685         685  509             Cody Zeller    C   26  CHO  49  1243  17.2
# 686         686  510            Tyler Zeller  F-C   29  ATL   1     7  -1.0
# 687         687  511              Ante Zizic    C   22  CLE  46   790  15.7
# 688         688  512             Ivica Zubac    C   21  TOT  44   731  18.8
# 689         689  512             Ivica Zubac    C   21  LAL  33   516  19.6
# 690         690  512             Ivica Zubac    C   21  LAC  11   215  16.8
#
#       TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 0    .507  ...    7.9  12.2   0.1  0.6   0.7    .053   -2.4  -1.0   -3.4  -0.2
# 1    .379  ...   15.2   9.2  -0.1  0.1  -0.1  -0.020   -5.7  -0.2   -5.9  -0.1
# 2    .542  ...   19.7  13.7   0.1  0.1   0.2    .046   -1.7  -2.1   -3.7  -0.1
# 3    .604  ...   12.6  16.4   4.5  3.3   7.8    .173    0.9   2.0    2.9   2.7
# 4    .621  ...   17.8  15.3   2.6  2.3   4.9    .164   -0.7   3.3    2.6   1.7
# 5    .405  ...   13.9   9.9  -0.2  0.0  -0.2  -0.065   -5.4  -1.7   -7.2  -0.2
# 6    .322  ...   15.5  24.8  -0.1  0.0   0.0  -0.046   -4.3   0.6   -3.7   0.0
# 7    .572  ...    9.2  27.2   4.9  2.0   6.9    .156    1.1   0.1    1.2   1.7
# 8    .375  ...    0.0  29.2   0.0  0.0   0.0    .354   20.0   7.3   27.4   0.0
# 9    .451  ...   11.6  21.6  -0.4  0.2  -0.2  -0.036   -4.7  -3.4   -8.1  -0.4
# 10   .630  ...   12.7  16.2   3.8  2.6   6.5    .176   -0.4   3.0    2.7   2.1
# 11   .578  ...   11.2  18.5   0.5  0.1   0.6    .137    1.2  -2.0   -0.8   0.1
# 12   .578  ...    9.8  13.1   2.7  2.2   4.9    .124    0.2   0.9    1.1   1.5
# 13   .459  ...   13.0  17.0  -0.2  0.2   0.0  -0.008   -4.7  -0.9   -5.6  -0.2
# 14   .569  ...   16.0  12.7   0.8  2.0   2.9    .107   -2.1   3.5    1.5   1.1
# 15   .437  ...   15.3  12.4  -0.2  0.0  -0.2  -0.029   -4.1  -2.1   -6.2  -0.3
# 16   .423  ...   15.4  12.1  -0.2  0.0  -0.2  -0.036   -4.4  -2.0   -6.4  -0.3
# 17   .595  ...   14.5  18.4   0.0  0.0   0.0    .101    1.3  -3.9   -2.6   0.0
# 18   .000  ...   25.0  29.2  -0.1  0.0  -0.1  -0.475  -22.6   8.6  -14.0   0.0
# 19   .640  ...   15.5  31.9   7.1  4.8  11.9    .283    5.3   5.1   10.4   6.3
# 20   .513  ...    5.8  20.4   0.1  0.2   0.3    .041   -3.0  -3.2   -6.2  -0.3
# 21   .538  ...    9.6  15.1   0.4  1.3   1.6    .070   -1.2  -0.1   -1.3   0.2
# 23   .588  ...   13.6  10.5   2.1  0.9   3.0    .088   -0.3  -0.8   -1.1   0.4
# 24   .537  ...   11.6  16.6   1.4  1.2   2.5    .056    0.1  -0.3   -0.2   1.0
# 25   .525  ...   13.7  13.8   0.2  0.5   0.7    .037   -1.2   0.4   -0.8   0.3
# 26   .543  ...   10.6  18.4   1.2  0.7   1.8    .068    0.9  -0.7    0.2   0.7
# 27   .631  ...   14.4  16.8   4.2  1.3   5.5    .145    1.8  -2.1   -0.3   0.8
# 28   .616  ...   11.2  21.0   4.1  1.5   5.6    .142    0.5   0.3    0.9   1.4
# 29   .610  ...   11.3  15.9   0.3  0.1   0.5    .071   -1.8  -2.5   -4.3  -0.2
# 30   .566  ...   11.7  23.1   1.4  1.3   2.7    .112   -1.4  -0.1   -1.4   0.2
# ..    ...  ...    ...   ...   ...  ...   ...     ...    ...   ...    ...   ...
# 661  .499  ...   16.8  31.5   0.9  4.0   4.9    .114    2.0   3.9    6.0   4.2
# 662  .572  ...   14.6  17.3   1.5  1.4   2.9    .106    0.2   1.0    1.2   1.1
# 663  .000  ...    0.0  14.1   0.0  0.0   0.0  -0.251  -11.0  -8.2  -19.2   0.0
# 664  .549  ...   11.6  22.6   1.5  3.2   4.8    .163   -2.6   3.0    0.4   0.9
# 665  .483  ...    9.0  24.1  -0.6  1.1   0.5    .012   -2.0  -1.2   -3.2  -0.6
# 666  .512  ...    9.3  26.7   0.0  0.0   0.1    .199   -1.9   0.7   -1.2   0.0
# 667  .441  ...   19.0  13.1  -0.1  0.0  -0.1  -0.055   -5.1  -3.2   -8.3  -0.1
# 668  .557  ...    4.4  14.4   0.2  0.1   0.3    .126   -1.4  -0.6   -1.9   0.0
# 669  .504  ...   11.6  12.7   0.2  0.6   0.8    .057   -1.2   0.3   -0.9   0.2
# 670  .555  ...   11.6  32.7   3.4  1.0   4.4    .130    3.5  -2.5    1.0   1.2
# 671  .558  ...    6.0  15.0   2.1  1.7   3.8    .097    0.3   0.4    0.6   1.2
# 672  .740  ...   16.0  11.0   0.5  0.5   1.0    .213   -1.8   6.7    5.0   0.4
# 673  .550  ...    7.9  14.7   0.2  0.3   0.5    .080   -2.0   0.1   -1.9   0.0
# 674   TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 675  .508  ...   11.2  13.7   0.1  1.0   1.0    .088   -2.9   1.4   -1.6   0.1
# 676  .515  ...   15.0  20.6   0.5  2.1   2.6    .073   -0.8   0.7   -0.1   0.8
# 677  .585  ...    8.7  23.5   0.1  0.1   0.2    .150   -3.3  -4.1   -7.3  -0.1
# 678  .521  ...   10.4  17.6   1.2  1.6   2.8    .112   -0.6   1.2    0.6   0.8
# 679  .527  ...   10.4  17.0   1.1  1.2   2.3    .121   -0.1   1.2    1.1   0.7
# 680  .505  ...   10.6  19.3   0.1  0.4   0.5    .084   -2.0   1.1   -0.9   0.1
# 681  .530  ...   15.6  18.7   0.1  0.3   0.4    .098   -2.0   0.9   -1.1   0.0
# 682  .500  ...   18.2  12.6   0.0  0.0   0.0  -0.019   -4.3  -2.7   -7.0   0.0
# 683  .568  ...   11.2  17.9   2.7  3.3   6.0    .143    0.9   2.2    3.1   2.6
# 684  .534  ...   18.7  28.0   1.4  0.6   1.9    .045    1.0  -2.9   -2.0   0.0
# 685  .611  ...   13.2  16.2   2.7  1.3   4.0    .153    0.4   1.7    2.1   1.3
# 686  .000  ...    0.0  11.7   0.0  0.0   0.0  -0.115  -10.4  -8.6  -19.0   0.0
# 687  .579  ...   13.2  18.0   1.1  0.3   1.4    .083   -2.4  -1.4   -3.8  -0.4
# 688  .601  ...   13.0  20.7   1.3  0.9   2.2    .147   -1.6   0.7   -0.9   0.2
# 689  .633  ...   12.9  20.5   1.2  0.6   1.8    .165   -1.2   0.2   -1.0   0.1
# 690  .526  ...   13.1  21.0   0.1  0.3   0.5    .105   -2.7   2.0   -0.7   0.1
#
# [688 rows x 28 columns]

# %%
#found another header row at row 99, removing
df.drop(df.index[99], inplace = True)

# %%
#found another header row at row 128, removing
df.drop(df.index[128], inplace = True)

# %%
#found another header row at row 150, removing
df.drop(df.index[150], inplace = True)

# %%
#found another header row at row 176, removing
df.drop(df.index[176], inplace = True)

# %%
#found another header row at row 204, removing
df.drop(df.index[204], inplace = True)

# %%
#found another header row at row 228, removing
df.drop(df.index[228], inplace = True)

# %%
#found another header row at row 252, removing
df.drop(df.index[252], inplace = True)

# %%
#found another header row at row 279, removing
df.drop(df.index[279], inplace = True)

# %%
#found another header row at row 303, removing
df.drop(df.index[303], inplace = True)

# %%
#found another header row at row 333, removing
df.drop(df.index[333], inplace = True)

# %%
#found another header row at row 363, removing
df.drop(df.index[363], inplace = True)

# %%
#found another header row at row 387, removing
df.drop(df.index[387], inplace = True)

# %%
#found another header row at row 420, removing
df.drop(df.index[420], inplace = True)

# %%
#found another header row at row 444, removing
df.drop(df.index[444], inplace = True)

# %%
#found another header row at row 470, removing
df.drop(df.index[470], inplace = True)

# %%
#found another header row at row 496, removing
df.drop(df.index[496], inplace = True)

# %%
#found another header row at row 522, removing
df.drop(df.index[522], inplace = True)

# %%
#found another header row at row 546, removing
df.drop(df.index[546], inplace = True)

# %%
#found another header row at row 580, removing
df.drop(df.index[580], inplace = True)

# %%
#found another header row at row 606, removing
df.drop(df.index[606], inplace = True)

# %%
#found another header row at row 628, removing
df.drop(df.index[628], inplace = True)

# %%
#found another header row at row 648, removing
df.drop(df.index[648], inplace = True)

# %%
#view df after removing header rows throughout df
print(df)
# Out:
#      Unnamed: 0   Rk                  Player  Pos  Age   Tm   G    MP   PER  \
# 0             0    1            Alex Abrines   SG   25  OKC  31   588   6.3
# 1             1    2              Quincy Acy   PF   28  PHO  10   123   2.9
# 2             2    3            Jaylen Adams   PG   22  ATL  19   181   9.6
# 3             3    4            Steven Adams    C   25  OKC  64  2167  19.0
# 4             4    5             Bam Adebayo    C   21  MIA  65  1448  17.1
# 5             5    6               Deng Adel   SF   21  CLE  12   158   2.2
# 6             6    7  DeVaughn Akoon-Purcell   SG   25  DEN   7    22   8.3
# 7             7    8       LaMarcus Aldridge    C   33  SAS  65  2132  22.5
# 8             8    9            Rawle Alkins   SG   21  CHI   3     6  37.9
# 9             9   10           Grayson Allen   SG   23  UTA  30   290   4.1
# 10           10   11           Jarrett Allen    C   20  BRK  66  1760  19.0
# 11           11   12            Kadeem Allen   SG   26  NYK  10   225  17.2
# 12           12   13         Al-Farouq Aminu   PF   28  POR  66  1911  13.2
# 13           13   14         Justin Anderson   SF   25  ATL  36   277   7.7
# 14           14   15           Kyle Anderson   SF   25  MEM  43  1281  12.9
# 15           15   16           Ryan Anderson   PF   30  TOT  19   294   5.1
# 16           16   16           Ryan Anderson   PF   30  PHO  15   278   4.6
# 17           17   16           Ryan Anderson   PF   30  MIA   4    16  13.4
# 18           18   17            Ike Anigbogu    C   20  IND   3     6  -6.0
# 19           19   18   Giannis Antetokounmpo   PF   24  MIL  61  2012  30.2
# 20           20   19         Carmelo Anthony   PF   34  HOU  10   294  11.0
# 21           21   20              OG Anunoby   SF   21  TOR  55  1121   9.7
# 23           23   21        Ryan Arcidiacono   PG   24  CHI  66  1624  10.7
# 24           24   22            Trevor Ariza   SF   33  TOT  62  2188  12.2
# 25           25   22            Trevor Ariza   SF   33  PHO  26   884  10.5
# 26           26   22            Trevor Ariza   SF   33  WAS  36  1304  13.4
# 27           27   23           D.J. Augustin   PG   31  ORL  66  1819  15.6
# 28           28   24           Deandre Ayton    C   20  PHO  61  1886  21.0
# 29           29   25            Dwayne Bacon   SG   23  CHO  27   309  11.0
# 30           30   26           Marvin Bagley   PF   19  SAC  47  1165  18.2
# ..          ...  ...                     ...  ...  ...  ...  ..   ...   ...
# 660         660  487            Thomas Welsh    C   22  DEN  10    33  12.4
# 661         661  488       Russell Westbrook   PG   30  OKC  58  2075  20.8
# 662         662  489           Derrick White   PG   24  SAS  51  1307  15.3
# 663         663  490             Okaro White   PF   26  WAS   3     6  -4.5
# 664         664  491        Hassan Whiteside    C   29  MIA  56  1405  22.6
# 665         665  492          Andrew Wiggins   SF   23  MIN  59  2053  11.9
# 666         666  493           Alan Williams   PF   26  BRK   3    17  25.0
# 667         667  494           C.J. Williams   SG   28  MIN   9    67   2.1
# 668         668  495      Johnathan Williams    C   23  LAL   9   133  13.6
# 669         669  496        Kenrich Williams   SF   24  NOP  32   670   9.8
# 670         670  497            Lou Williams   SG   32  LAC  61  1620  21.7
# 671         671  498         Marvin Williams   PF   32  CHO  65  1874  13.0
# 673         673  500           Troy Williams   SF   24  SAC  18   286  11.1
# 674         674   Rk                  Player  Pos  Age   Tm   G    MP   PER
# 675         675  501             D.J. Wilson   PF   22  MIL  34   575   9.8
# 676         676  502         Justise Winslow   PF   22  MIA  58  1729  13.1
# 677         677  503          Christian Wood   PF   23  MIL  13    62  17.3
# 678         678  504            Delon Wright   PG   26  TOT  60  1205  14.4
# 679         679  504            Delon Wright   PG   26  TOR  49   897  14.6
# 680         680  504            Delon Wright   PG   26  MEM  11   308  13.7
# 681         681  505      Guerschon Yabusele   PF   23  BOS  33   178  13.1
# 682         682  506              Nick Young   SG   33  DEN   4    37   2.4
# 683         683  507          Thaddeus Young   PF   30  IND  66  2016  16.6
# 684         684  508              Trae Young   PG   20  ATL  67  2061  15.9
# 685         685  509             Cody Zeller    C   26  CHO  49  1243  17.2
# 686         686  510            Tyler Zeller  F-C   29  ATL   1     7  -1.0
# 687         687  511              Ante Zizic    C   22  CLE  46   790  15.7
# 688         688  512             Ivica Zubac    C   21  TOT  44   731  18.8
# 689         689  512             Ivica Zubac    C   21  LAL  33   516  19.6
# 690         690  512             Ivica Zubac    C   21  LAC  11   215  16.8
#
#       TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 0    .507  ...    7.9  12.2   0.1  0.6   0.7    .053   -2.4  -1.0   -3.4  -0.2
# 1    .379  ...   15.2   9.2  -0.1  0.1  -0.1  -0.020   -5.7  -0.2   -5.9  -0.1
# 2    .542  ...   19.7  13.7   0.1  0.1   0.2    .046   -1.7  -2.1   -3.7  -0.1
# 3    .604  ...   12.6  16.4   4.5  3.3   7.8    .173    0.9   2.0    2.9   2.7
# 4    .621  ...   17.8  15.3   2.6  2.3   4.9    .164   -0.7   3.3    2.6   1.7
# 5    .405  ...   13.9   9.9  -0.2  0.0  -0.2  -0.065   -5.4  -1.7   -7.2  -0.2
# 6    .322  ...   15.5  24.8  -0.1  0.0   0.0  -0.046   -4.3   0.6   -3.7   0.0
# 7    .572  ...    9.2  27.2   4.9  2.0   6.9    .156    1.1   0.1    1.2   1.7
# 8    .375  ...    0.0  29.2   0.0  0.0   0.0    .354   20.0   7.3   27.4   0.0
# 9    .451  ...   11.6  21.6  -0.4  0.2  -0.2  -0.036   -4.7  -3.4   -8.1  -0.4
# 10   .630  ...   12.7  16.2   3.8  2.6   6.5    .176   -0.4   3.0    2.7   2.1
# 11   .578  ...   11.2  18.5   0.5  0.1   0.6    .137    1.2  -2.0   -0.8   0.1
# 12   .578  ...    9.8  13.1   2.7  2.2   4.9    .124    0.2   0.9    1.1   1.5
# 13   .459  ...   13.0  17.0  -0.2  0.2   0.0  -0.008   -4.7  -0.9   -5.6  -0.2
# 14   .569  ...   16.0  12.7   0.8  2.0   2.9    .107   -2.1   3.5    1.5   1.1
# 15   .437  ...   15.3  12.4  -0.2  0.0  -0.2  -0.029   -4.1  -2.1   -6.2  -0.3
# 16   .423  ...   15.4  12.1  -0.2  0.0  -0.2  -0.036   -4.4  -2.0   -6.4  -0.3
# 17   .595  ...   14.5  18.4   0.0  0.0   0.0    .101    1.3  -3.9   -2.6   0.0
# 18   .000  ...   25.0  29.2  -0.1  0.0  -0.1  -0.475  -22.6   8.6  -14.0   0.0
# 19   .640  ...   15.5  31.9   7.1  4.8  11.9    .283    5.3   5.1   10.4   6.3
# 20   .513  ...    5.8  20.4   0.1  0.2   0.3    .041   -3.0  -3.2   -6.2  -0.3
# 21   .538  ...    9.6  15.1   0.4  1.3   1.6    .070   -1.2  -0.1   -1.3   0.2
# 23   .588  ...   13.6  10.5   2.1  0.9   3.0    .088   -0.3  -0.8   -1.1   0.4
# 24   .537  ...   11.6  16.6   1.4  1.2   2.5    .056    0.1  -0.3   -0.2   1.0
# 25   .525  ...   13.7  13.8   0.2  0.5   0.7    .037   -1.2   0.4   -0.8   0.3
# 26   .543  ...   10.6  18.4   1.2  0.7   1.8    .068    0.9  -0.7    0.2   0.7
# 27   .631  ...   14.4  16.8   4.2  1.3   5.5    .145    1.8  -2.1   -0.3   0.8
# 28   .616  ...   11.2  21.0   4.1  1.5   5.6    .142    0.5   0.3    0.9   1.4
# 29   .610  ...   11.3  15.9   0.3  0.1   0.5    .071   -1.8  -2.5   -4.3  -0.2
# 30   .566  ...   11.7  23.1   1.4  1.3   2.7    .112   -1.4  -0.1   -1.4   0.2
# ..    ...  ...    ...   ...   ...  ...   ...     ...    ...   ...    ...   ...
# 660  .589  ...    7.8  16.5   0.1  0.0   0.1    .111   -0.2  -4.0   -4.2   0.0
# 661  .499  ...   16.8  31.5   0.9  4.0   4.9    .114    2.0   3.9    6.0   4.2
# 662  .572  ...   14.6  17.3   1.5  1.4   2.9    .106    0.2   1.0    1.2   1.1
# 663  .000  ...    0.0  14.1   0.0  0.0   0.0  -0.251  -11.0  -8.2  -19.2   0.0
# 664  .549  ...   11.6  22.6   1.5  3.2   4.8    .163   -2.6   3.0    0.4   0.9
# 665  .483  ...    9.0  24.1  -0.6  1.1   0.5    .012   -2.0  -1.2   -3.2  -0.6
# 666  .512  ...    9.3  26.7   0.0  0.0   0.1    .199   -1.9   0.7   -1.2   0.0
# 667  .441  ...   19.0  13.1  -0.1  0.0  -0.1  -0.055   -5.1  -3.2   -8.3  -0.1
# 668  .557  ...    4.4  14.4   0.2  0.1   0.3    .126   -1.4  -0.6   -1.9   0.0
# 669  .504  ...   11.6  12.7   0.2  0.6   0.8    .057   -1.2   0.3   -0.9   0.2
# 670  .555  ...   11.6  32.7   3.4  1.0   4.4    .130    3.5  -2.5    1.0   1.2
# 671  .558  ...    6.0  15.0   2.1  1.7   3.8    .097    0.3   0.4    0.6   1.2
# 673  .550  ...    7.9  14.7   0.2  0.3   0.5    .080   -2.0   0.1   -1.9   0.0
# 674   TS%  ...   TOV%  USG%   OWS  DWS    WS   WS/48   OBPM  DBPM    BPM  VORP
# 675  .508  ...   11.2  13.7   0.1  1.0   1.0    .088   -2.9   1.4   -1.6   0.1
# 676  .515  ...   15.0  20.6   0.5  2.1   2.6    .073   -0.8   0.7   -0.1   0.8
# 677  .585  ...    8.7  23.5   0.1  0.1   0.2    .150   -3.3  -4.1   -7.3  -0.1
# 678  .521  ...   10.4  17.6   1.2  1.6   2.8    .112   -0.6   1.2    0.6   0.8
# 679  .527  ...   10.4  17.0   1.1  1.2   2.3    .121   -0.1   1.2    1.1   0.7
# 680  .505  ...   10.6  19.3   0.1  0.4   0.5    .084   -2.0   1.1   -0.9   0.1
# 681  .530  ...   15.6  18.7   0.1  0.3   0.4    .098   -2.0   0.9   -1.1   0.0
# 682  .500  ...   18.2  12.6   0.0  0.0   0.0  -0.019   -4.3  -2.7   -7.0   0.0
# 683  .568  ...   11.2  17.9   2.7  3.3   6.0    .143    0.9   2.2    3.1   2.6
# 684  .534  ...   18.7  28.0   1.4  0.6   1.9    .045    1.0  -2.9   -2.0   0.0
# 685  .611  ...   13.2  16.2   2.7  1.3   4.0    .153    0.4   1.7    2.1   1.3
# 686  .000  ...    0.0  11.7   0.0  0.0   0.0  -0.115  -10.4  -8.6  -19.0   0.0
# 687  .579  ...   13.2  18.0   1.1  0.3   1.4    .083   -2.4  -1.4   -3.8  -0.4
# 688  .601  ...   13.0  20.7   1.3  0.9   2.2    .147   -1.6   0.7   -0.9   0.2
# 689  .633  ...   12.9  20.5   1.2  0.6   1.8    .165   -1.2   0.2   -1.0   0.1
# 690  .526  ...   13.1  21.0   0.1  0.3   0.5    .105   -2.7   2.0   -0.7   0.1
#
# [666 rows x 28 columns]

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0    0
# Rk            0
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# MP            0
# PER           0
# TS%           6
# 3PAr          8
# FTr           8
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          6
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# dtype: int64

# %%
#change necessary columns to correct type
df[["Age","G","MP", "PER", "TS%", "3PAr", "FTr", "ORB%", "DRB%", "TRB%", "AST%", "STL%", "BLK%", "TOV%", "USG%", 
    "OWS","DWS", "WS", "WS/48", "OBPM", "DBPM", "BPM", "VORP"]] = df[["Rk", "Age","G","MP", "PER", "TS%", "3PAr", "FTr", "ORB%", "DRB%", "TRB%", "AST%", "STL%", "BLK%", "TOV%", "USG%", 
    "OWS","DWS", "WS", "WS/48", "OBPM", "DBPM", "BPM", "VORP"]].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Rk"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-5b794d07e79a> in <module>
#       2 df[["Age","G","MP", "PER", "TS%", "3PAr", "FTr", "ORB%", "DRB%", "TRB%", "AST%", "STL%", "BLK%", "TOV%", "USG%",
#       3     "OWS","DWS", "WS", "WS/48", "OBPM", "DBPM", "BPM", "VORP"]] = df[["Rk", "Age","G","MP", "PER", "TS%", "3PAr", "FTr", "ORB%", "DRB%", "TRB%", "AST%", "STL%", "BLK%", "TOV%", "USG%",
# ----> 4     "OWS","DWS", "WS", "WS/48", "OBPM", "DBPM", "BPM", "VORP"]].apply(pd.to_numeric)
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# D:\Anaconda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: ('Unable to parse string "Rk" at position 607', 'occurred at index Rk')

# %%
df['WS'].max()
# Out:
# 'WS'

# %%
df['WS'].min()
# Out:
# '-0.1'
